# %% [markdown]
# ## 1 Normality Check

# %% [markdown]
# ### 1.1 Histogram

# %% [markdown]
# ### 1.2 Q-Q Plot

# %% [markdown]
# ### 1.3 Shapiro-Wilkinson Test

# %% [markdown]
# ## Shapiro-Wilkinson Test

# %% [markdown]
# ### Nature of Hypothesis

# %% [markdown]
# ### API

# %% [markdown]
# ```python
# from scipy.stats import shapiro
# ```

# %% [markdown]
# ### Examples

# %%
from scipy.stats import shapiro
