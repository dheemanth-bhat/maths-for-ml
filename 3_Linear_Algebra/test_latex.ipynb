# %% [markdown]
# ### 1 Type `align`

# %% [markdown]
# #### 1.1 `align` Wrapped in single \$ block

# %% [markdown]
# $
# \begin{align}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{align}
# $

# %% [markdown]
# #### 1.2 `align` Wrapped in double \$\$ block

# %% [markdown]
# $$
# \begin{align}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{align}
# $$

# %% [markdown]
# #### 1.3 `align` Not wrapped in \$ block

# %% [markdown]
# \begin{align}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{align}

# %% [markdown]
# ### 2 Type `aligned`

# %% [markdown]
# #### 2.1 `aligned` Wrapped in single \$ block

# %% [markdown]
# $
# \begin{aligned}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{aligned}
# $

# %% [markdown]
# #### 2.2 `aligned` Wrapped in double \$\$ block

# %% [markdown]
# $$
# \begin{aligned}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{aligned}
# $$

# %% [markdown]
# #### 2.3 `aligned` Not wrapped in \$ block

# %% [markdown]
# \begin{aligned}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{aligned}

# %% [markdown]
# ### 3 Type `equation`

# %% [markdown]
# #### 3.1 `equation` Wrapped in single \$ block

# %% [markdown]
# $
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}
# $

# %% [markdown]
# #### 3.2 `equation` Wrapped in double \$\$ block

# %% [markdown]
# $$
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}
# $$

# %% [markdown]
# #### 3.3 `equation` Not wrapped in \$ block

# %% [markdown]
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}

# %% [markdown]
# ### 4 HTML div

# %% [markdown]
# #### 4.1 HTML div Wrapped in single \$ block.

# %% [markdown]
# <div style="text-align: left;">
# $
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}
# $
# </div>

# %% [markdown]
# #### 4.2 HTML div Wrapped in double \$\$ block.

# %% [markdown]
# <div style="text-align: left;">
# $$
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}
# $$
# </div>

# %% [markdown]
# #### 4.3 HTML div Not wrapped in \$ block.

# %% [markdown]
# <div style="text-align: left;">
# \begin{equation}
# \text{Demand-Supply-Gap} = \frac{\text{Demand} - \text{Supply}}{\text{Demand}}
# \end{equation}
# </div>
